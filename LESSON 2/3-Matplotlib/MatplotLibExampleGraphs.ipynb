# %% [markdown]
# # MatplotLib

# %%
# Example: plot points

import matplotlib.pyplot as plt
# Define x and y coordinates
x = [0, 2, 4, 6]
y = [0, 50, 150, 250]
# Plot the points
plt.plot(x, y)
# Add title and labels
plt.title("Plotting x and y Points")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Show the graph
plt.show()

# %%
#Example : Draw a line connection 2 points (0,0) to (6,250)
#this example demonstrates that plt connects points by defualt
# Data points
x = [0, 6]
y = [0, 250]

# Plot the line
plt.plot(x, y,linestyle='--', marker='o', color='r')

# Label the graph
plt.title("Drawing a Line")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Display the plot
plt.show()

# %%
# Example: Adding grid lines for better readability

import matplotlib.pyplot as plt
# Data points
x = [0, 2, 4, 6]
y = [0, 50, 150, 250]
# Plot with grid
plt.plot(x, y, marker='o')
plt.grid()

# Add title and labels
plt.title("Line Plot with Grid")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Show plot
plt.show()

# %%
#Example: plot multiple lines on the same graph

#You can plot multiple lines on the same graph by calling plot() multiple times or passing
#additional x, y pairs

# Line 1 data
x1 = [0, 2, 4, 6]
y1 = [0, 50, 150, 250]
# Line 2 data
x2 = [0, 2, 4, 6]
y2 = [0, 30, 90, 180]
# Plot the first line
plt.plot(x1, y1, label='Line 1', color='b', marker='o')
# Plot the second line
plt.plot(x2, y2, label='Line 2', color='g', linestyle='--')
# Add title, labels, legend, and grid
plt.title("Multiple Lines on One Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid()
# Show the plot
plt.show()

# %% [markdown]
# ## Hands on experience
#
# 1. Plot a line connecting (0,0), (3,100), and (6,200) with square markers and a dashed line.
# 2. Add a grid to the graph and customize its color and stylem.

# %%
x1= [0,3,6]
y1=[0,100,200]

plt.plot(x1,y1, color='r', marker='s')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5)

# %%
# Example without lines - string parameter 'o'
import numpy as np
x = np.array([0, 6])
y = np.array([0, 250])
plt.plot(x, y, 'o')
plt.show()

# %%
# Example: DEFAULT X AXIS
# if no x axis is specified, then the indices of the y array are the x axis values

y = np.array([3, 8, 1, 10, 5, 7])
plt.plot(y)
plt.show()

# %%
# Example: label for axes
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 8, 12, 20, 26, 38])
plt.plot(x, y)
plt.xlabel("Overs")
plt.ylabel("Runs")
plt.show()

# %%
# Example: adding a title and custom fonts and colors for axes
font1 = {'family': 'serif', 'color': 'blue', 'size': 20}
font2 = {'family': 'serif', 'color': 'darkred', 'size': 15}
plt.xlabel("Overs", fontdict=font2)
plt.ylabel("Runs", fontdict=font2)
plt.title("Sport Data", fontdict=font1)
plt.show()

# %% [markdown]
# ### Scatter Plots
# using .scatter()

# %%
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 8, 12, 20, 26, 38])
font1 = {'family': 'serif', 'color': 'blue', 'size': 20}
font2 = {'family': 'serif', 'color': 'darkred', 'size': 15}
plt.scatter(x, y)
plt.xlabel('Overs', fontdict=font2)
plt.ylabel('Runs', fontdict=font2)
plt.title('Sport Data', fontdict=font1)
plt.show()

# %%
#Example: subplots
# Plot 1
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
plt.subplot(2, 1, 1)
plt.plot(x1, y1)
# Plot 2
x2 = np.array([0, 1, 2, 3])
y2 = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2)
plt.plot(x2, y2)
plt.show()

# %% [markdown]
# ### Bar Graph
# .bar()

# %%
x = np.array(['A', 'B', 'C', 'D'])
y = np.array([3, 8, 1, 10])
plt.bar(x, y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Histogrrams
# .hist()

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x)
# Out:
# (array([ 8., 20., 50., 60., 41., 41., 23.,  6.,  0.,  1.]),
#  array([143.95048843, 150.32831157, 156.70613471, 163.08395785,
#         169.46178098, 175.83960412, 182.21742726, 188.5952504 ,
#         194.97307353, 201.35089667, 207.72871981]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Pie charts
# .pie()

# %%
x = np.array([35, 25, 25, 15])
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa0a2aad410>,
# ...
#  [Text(0.4993895680663529, 0.9801071672559597, ''),
#   Text(-1.086457168210212, 0.17207795223283895, ''),
#   Text(-0.172077952232839, -1.086457168210212, ''),
#   Text(0.9801071672559598, -0.4993895680663526, '')])
